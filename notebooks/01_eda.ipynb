# %% [markdown]
# **Step 1: Importing all necessary libraries for EDA**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the dataset

clv_df = pd.read_csv(r"C:\Users\Collins Njagi\Documents\Data_Science_tech_class\clv-regression-retail-finserv\clv_dataset.csv")

clv_df.head()
# Out:
#   customer_id        age  gender region customer_segment  tenure_months  \
# 0     C000001        NaN    Male    NaN            Basic      41.782826
# 1     C000002  59.960182    Male    NaN         Standard      24.676991
# 2     C000003  49.244677  Female  South         Standard      24.751584
# 3     C000004  22.405579  Female   West            Basic      14.250395
# 4     C000005  36.320996  Female    NaN         Standard      27.340128
#
#    avg_monthly_spend  avg_transaction_value  purchase_frequency  \
# 0         478.147262             104.480104           15.500257
# 1         414.103659             144.542648           19.131489
# 2         395.523475             143.348133           12.786573
# 3        1208.645086             156.953659            3.647866
# 4         499.168096              44.189692           10.229082
#
#    num_products_owned  engagement_score  churn_risk_score  satisfaction_score  \
# ...

# %%
clv_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               15000 non-null  str
#  1   age                       12500 non-null  float64
#  2   gender                    15000 non-null  str
#  3   region                    9000 non-null   str
#  4   customer_segment          15000 non-null  str
#  5   tenure_months             15000 non-null  float64
#  6   avg_monthly_spend         15000 non-null  float64
#  7   avg_transaction_value     12500 non-null  float64
#  8   purchase_frequency        15000 non-null  float64
#  9   num_products_owned        15000 non-null  int64
#  10  engagement_score          15000 non-null  float64
#  11  churn_risk_score          12500 non-null  float64
#  12  satisfaction_score        12500 non-null  float64
#  13  email_open_rate           12500 non-null  float64
# ...

# %%
clv_df.describe()
# Out:
#                 age  tenure_months  avg_monthly_spend  avg_transaction_value  \
# count  12500.000000   15000.000000       15000.000000           12500.000000
# mean      45.324942      23.983111         498.862721             149.401165
# std       14.384654      13.890450         222.745751              85.055486
# min       18.000000       1.000000          39.185138               5.000000
# 25%       34.952307      13.797306         334.889185              87.067546
# 50%       45.259362      21.264697         465.923007             133.510606
# 75%       55.209986      31.384745         627.732330             194.236809
# max       80.000000     120.000000        1729.118237             655.943759
#
#        purchase_frequency  num_products_owned  engagement_score  \
# count        15000.000000        15000.000000      15000.000000
# mean            11.989860            3.068800         71.389229
# std              8.416213            1.689494         15.956685
# ...

# %% [markdown]
# **Checking for  Duplicates**

# %%
clv_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#clv_df['region'].unique()
#clv_df['customer_segment'].unique()
#clv_df['preferred_channel'].unique()
#clv_df['payment_method'].unique()

cat_cols = clv_df.select_dtypes(include = 'object')
# Out:
# C:\Users\Collins Njagi\AppData\Local\Temp\ipykernel_20368\846144353.py:7: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   clv_df.select_dtypes(include = 'object')
#       customer_id  gender region customer_segment preferred_channel  \
# 0         C000001    Male    NaN            Basic               NaN
# 1         C000002    Male    NaN         Standard          In-Store
# 2         C000003  Female  South         Standard            Online
# 3         C000004  Female   West            Basic            Online
# ...

# %%
# Preferred: get column NAMES (Index) rather than the whole dataframe
cat_cols = clv_df.select_dtypes(include='object').columns
# show the categorical columns
print('Categorical columns:', list(cat_cols))

# Loop: print number of unique values and top frequencies for each categorical column
for col in cat_cols:
    print(f"\nColumn: {col} — {clv_df[col].nunique()} unique values")
    print(clv_df[col].value_counts(dropna=False).head(10))
